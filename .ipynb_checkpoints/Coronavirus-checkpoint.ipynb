# %% [markdown]
# # **Coronavirus**

# %%
import datetime
import numpy as np
from scipy.optimize import curve_fit
import pandas as pd
import matplotlib.pyplot as plt
import sympy as sp

# %% [markdown]
# ### Importing data

# %% [markdown]
# Creare dataframe regioni e province

# %%
df_ita = pd.read_csv(r"~/github/COVID-19/dati-andamento-nazionale/dpc-covid19-ita-andamento-nazionale.csv")
df_ita
# Out:
#                     data stato  ricoverati_con_sintomi  terapia_intensiva  \
# 0    2020-02-24T18:00:00   ITA                     101                 26
# 1    2020-02-25T18:00:00   ITA                     114                 35
# 2    2020-02-26T18:00:00   ITA                     128                 36
# 3    2020-02-27T18:00:00   ITA                     248                 56
# 4    2020-02-28T18:00:00   ITA                     345                 64
# ..                   ...   ...                     ...                ...
# 251  2020-11-01T17:00:00   ITA                   18902               1939
# 252  2020-11-02T17:00:00   ITA                   19840               2022
# 253  2020-11-03T17:00:00   ITA                   21114               2225
# 254  2020-11-04T17:00:00   ITA                   22116               2292
# 255  2020-11-05T17:00:00   ITA                   23256               2391
#
#      totale_ospedalizzati  isolamento_domiciliare  totale_positivi  \
# ...
